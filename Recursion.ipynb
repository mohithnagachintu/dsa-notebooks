# %% [markdown]
# ##### 1. Generate all Binary strings with no consecutive 1s.

# %% [markdown]
# ##### 2. Generate all parenthesis

# %% [markdown]
# ##### 3. Power Set: Print all the possible subsequences of the String

# %% [markdown]
# ##### 4. Distinct Subsequences

# %% [markdown]
# ##### 5.  Count all subsequences with sum K

# %% [markdown]
# ##### 6. Combination Sum

# %% [markdown]
# ##### 7. Combination Sum II

# %% [markdown]
# ##### 8. Subset Sum

# %% [markdown]
# ##### 9. Subset Sum II

# %% [markdown]
# ##### 10. Combination Sum III

# %% [markdown]
# ##### 11. Letter Phone (Coding Ninjas)

# %% [markdown]
# ##### 12. Palindrome Partioning

# %% [markdown]
# ##### 13. Word Search

# %% [markdown]
# ##### 14. N Queen

# %% [markdown]
# ##### 15. Rat in a Maze

# %% [markdown]
# ##### 16. Word Break

# %% [markdown]
# ##### 17. M Coloring Problem

# %% [markdown]
# ##### 18. Sudoko Solver

# %% [markdown]
# ##### 19. Expression Add Operators
