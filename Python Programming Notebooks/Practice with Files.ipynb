# %% [markdown]
# # Text File I/O

# %% [markdown]
# ### Opening a file

# %%
fp = open('myfile.txt', 'w')

# %% [markdown]
# ### Writing contents into file

# %%
fp.write('This is a sample text file\n')
# Out:
# 27

# %% [markdown]
# ### Closing the file

# %%
fp.close()

# %%
fp = open('myfile.txt', 'a')
fp.write('This is second line\n')
fp.write('This is third line\n')
fp.write('This is fourth line\n')
fp.close()

# %%
f = open('sample.txt','w')
f.write('hello\n')
f.write('i am mohith\n')
f.close()

# %%
f1= open('sample.txt','a')
f1.write('i want to become a data scientist\n')
f1.close()

# %%
f2 = open('sample.txt','r')
print(f2.readlines())
f2.close()
# Out:
# ['hello\n', 'i am mohith\n', 'i want to become a data scientist\n']

# %%
with open('sample.txt','r') as f3:
    line = f3.readline()
    while line:
        print(line,end = '')
        line = f3.readline()
# Out:
# hello
# i am mohith
# i want to become a data scientist

# %% [markdown]
# ### Reading contents from file

# %%
fp = open('myfile.txt', 'r')
print(fp.readlines())
fp.close()
# Out:
# ['This is a sample text file\n', 'This is second line\n', 'This is third line\n', 'This is fourth line\n']

# %%
with open('myfile.txt') as fp:
    line = fp.readline()
    while line:
        print(line,end='')
        line = fp.readline()
# Out:
# This is a sample text file
# This is second line
# This is third line
# This is fourth line

# %%
for line in open('myfile.txt'):
    print(line, end='')
# Out:
# This is a sample text file
# This is second line
# This is third line
# This is fourth line

# %% [markdown]
# ### Reading and Writing list of string items

# %%
MyStrings = ['This is First Line', 'This is Second Line', 'This is Third Line']
with open('mylist.txt', 'w') as fp:
    for mystr in MyStrings:
        fp.write(mystr+'\n')
contents = []
for line in open('mylist.txt'):
    contents.append(line)
print(contents)
# Out:
# ['This is First Line\n', 'This is Second Line\n', 'This is Third Line\n']

# %%
l = ['mohith','naga','appasamudram','cse','SASTRA UNIVERSITY','data scientist']
with open('sample.txt','a') as f4:
    for x in l:
        f4.write(x+'\n')

# %%
c1 = []
for line in open('sample.txt'):
    c1.append(line)
print(c1)
# Out:
# ['hello\n', 'i am mohith\n', 'i want to become a data scientist\n', 'mohith\n', 'naga\n', 'appasamudram\n', 'cse\n', 'SASTRA UNIVERSITY\n', 'data scientist\n']

# %% [markdown]
# ### Reading and Writing list of numbers

# %%
MyNumbers = [45, 56, 90, 23, 11, 8]
with open('mylist.txt', 'w') as fp:
    for num in MyNumbers:
        fp.write(str(num)+'\n')
contents = []
for num in open('mylist.txt'):
    contents.append(int(num))
print(contents)
# Out:
# [45, 56, 90, 23, 11, 8]

# %%
l2 = [3,5,3,5,2,5,2,6,2,5,2,66,3,6,3,6,3,6]
with open('sample2.txt','w') as fp:
    for n in l2:
        fp.write(str(n)+'\n')                  # write argument must be str

c1 = []
for n in open('sample2.txt'):
    c1.append(int(n))
print(c1)
# Out:
# [3, 5, 3, 5, 2, 5, 2, 6, 2, 5, 2, 66, 3, 6, 3, 6, 3, 6]

# %%
fp = open('sample2.txt','w')
fp.write(str(l2)+'\n')
fp.close()
fp = open('sample2.txt','r')
num = fp.read()
print(type(num))
print(num)
# Out:
# <class 'str'>
# [3, 5, 3, 5, 2, 5, 2, 6, 2, 5, 2, 66, 3, 6, 3, 6, 3, 6]

# %%
fp = open('sample2.txt')
num = eval(fp.read())
print(type(num))
print(num)
# Out:
# <class 'list'>
# [3, 5, 3, 5, 2, 5, 2, 6, 2, 5, 2, 66, 3, 6, 3, 6, 3, 6]

# %%
MyNumbers = [45, 56, 90, 23, 11, 8]
with open('mylist.txt', 'w') as fp:
    fp.write(str(MyNumbers)+'\n')
fp = open('mylist.txt')
numbers = fp.read()
print(type(numbers))
print(numbers)
# Out:
# <class 'str'>
# [45, 56, 90, 23, 11, 8]

# %%
MyNumbers = [45, 56, 90, 23, 11, 8]
with open('mylist.txt', 'w') as fp:
    fp.write(str(MyNumbers)+'\n')
fp = open('mylist.txt')
numbers = eval(fp.read())
print(type(numbers))
print(numbers)
# Out:
# <class 'list'>
# [45, 56, 90, 23, 11, 8]

# %%
MyDict = {'A':45, 'B':56, 'C':90, 'D':23, 'E':11, 'F':8}
with open('mydict.txt', 'w') as fp:
    fp.write(str(MyDict)+'\n')
fp = open('mydict.txt')
dic = eval(fp.read())
print(type(dic))
print(dic)
# Out:
# <class 'dict'>
# {'A': 45, 'B': 56, 'C': 90, 'D': 23, 'E': 11, 'F': 8}

# %%
d = {32:'mohith',225:"thor",143:"meow",178:"visnu",238:"ranjith"}
with open('sample3.txt','w') as fp:
    fp.write(str(d)+'\n')
fp = open('sample3.txt','r')
d1 = eval(fp.read())
print(type(d1))
print(d1)
# Out:
# <class 'dict'>
# {32: 'mohith', 225: 'thor', 143: 'meow', 178: 'visnu', 238: 'ranjith'}

# %%
MyNumbers = (45, 56, 90, 23, 11, 8)
with open('mytuple.txt', 'w') as fp:
    fp.write(str(MyNumbers)+'\n')
fp = open('mytuple.txt')
numbers = eval(fp.read())
print(type(numbers))
print(numbers)
# Out:
# <class 'tuple'>
# (45, 56, 90, 23, 11, 8)

# %%
MyNumbers = {45, 56, 90, 23, 11, 8}
with open('myset.txt', 'w') as fp:
    fp.write(str(MyNumbers)+'\n')
fp = open('myset.txt')
numbers = eval(fp.read())
print(type(numbers))
print(numbers)
# Out:
# <class 'set'>
# {90, 23, 8, 56, 11, 45}

# %% [markdown]
# # Handling CSV Files

# %%
l = [['mohith',20,'cse'],['kasi',19,'cse'],['meow',20,'cse'],['ranjith',20,'cse'],['vishnu',18,'cse']]

# %%
import csv
with open('fr.csv','w',newline='') as fp:
    w = csv.writer(fp)
    w.writerows(l)
    
with open('fr.csv','r',newline='') as fp:
    r = csv.reader(fp)
    for row in r:
        print(row)
# Out:
# ['mohith', '20', 'cse']
# ['kasi', '19', 'cse']
# ['meow', '20', 'cse']
# ['ranjith', '20', 'cse']
# ['vishnu', '18', 'cse']

# %%
with open('fr.csv','a',newline = '') as fp:
    w = csv.writer(fp,delimiter = ',',quotechar = '"',quoting = csv.QUOTE_MINIMAL)
    w.writerow(['yaswanth',21,'it'])

# %%
import csv
with open('myfile.csv', 'w', newline='') as fp:
    w_obj = csv.writer(fp)
    mylist =[['Ram', 'Manager', 75000], ['Lakshmi', 'Asst. Manager', 60000], ['Kumar', 'Clerk', 30000], ['Raja', 'Peon', 10000]]
    w_obj.writerows(mylist)

# %%
with open('myfile.csv', 'r', newline='') as fp:
    r_obj = csv.reader(fp)
    for row in r_obj:
        print(row)
# Out:
# ['Ram', 'Manager', '75000']
# ['Lakshmi', 'Asst. Manager', '60000']
# ['Kumar', 'Clerk', '30000']
# ['Raja', 'Peon', '10000']

# %%
with open('employee_file.csv', mode='w',newline='') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    employee_writer.writerow(['Kumar', 'Marketing', 'January'])
    employee_writer.writerow(['Raja', 'Finance', 'May'])

# %%
with open('employee_file.csv') as employee_file:
    employee_reader = csv.reader(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for row in employee_reader:
        print(row)
# Out:
# ['Kumar', 'Marketing', 'January']
# ['Raja', 'Finance', 'May']

# %%
with open('employee_file2.csv', mode='w', newline='') as csv_file:
    fieldnames = ['emp_name', 'dept', 'birth_month']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'emp_name': 'Ram', 'dept': 'Accounting', 'birth_month': 'November'})
    writer.writerow({'emp_name': 'Lakshmi', 'dept': 'IT', 'birth_month': 'March'})

# %%
with open('employee_file2.csv') as employee_file:
    employee_reader = csv.DictReader(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for row in employee_reader:
        print(row)
# Out:
# OrderedDict([('emp_name', 'Ram'), ('dept', 'Accounting'), ('birth_month', 'November')])
# OrderedDict([('emp_name', 'Lakshmi'), ('dept', 'IT'), ('birth_month', 'March')])

# %%
with open('employee_file2.csv') as employee_file:
    employee_reader = csv.DictReader(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for row in employee_reader:
        print('Name:', row['emp_name'], '\nDepartment:', row['dept'], '\nBirth Month:', row['birth_month'])
# Out:
# Name: Ram
# Department: Accounting
# Birth Month: November
# Name: Lakshmi
# Department: IT
# Birth Month: March

# %%
with open('employee_file.csv') as employee_file:
    employee_reader = csv.DictReader(employee_file, fieldnames=['emp_name', 'dept', 'birth_month'])
    for row in employee_reader:
        print('Name:', row['emp_name'], '\nDepartment:', row['dept'], '\nBirth Month:', row['birth_month'])
# Out:
# Name: Kumar
# Department: Marketing
# Birth Month: January
# Name: Raja
# Department: Finance
# Birth Month: May

# %% [markdown]
# # Binary File I/O

# %%
import pickle
MyStrings = ['This is First Line', 'This is Second Line', 'This is Third Line']
with open('myfile.bin', 'wb') as fp:
    pickle.dump(MyStrings, fp)

# %%
with open('myfile.bin', 'rb') as fp:
    MyStrings = pickle.load(fp)
    print(MyStrings)
# Out:
# ['This is First Line', 'This is Second Line', 'This is Third Line']
