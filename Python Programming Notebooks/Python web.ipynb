# %%
import xml.etree.ElementTree as ET

# %%
string = '''
<stuff>
  <users>
    <user x="2">
      <id>001</id>
      <name>Chuck</name>
    </user>
    <user x="7">
      <id>009</id>
      <name>Brent</name>
    </user>
  </users>
</stuff>
'''

# %%
tree = ET.fromstring(string)
lst = tree.findall('users/user')
print(lst)
print('no. of items : ',len(lst))
for item in lst:
    print('name : ',item.find('name').text)
    print('id: ',item.find('id').text)
    print('attribute of x ',item.get('x') )
# Out:
# [<Element 'user' at 0x000002B6095C2728>, <Element 'user' at 0x000002B6095C2818>]
# no. of items :  2
# name :  Chuck
# id:  001
# attribute of x  2
# name :  Brent
# id:  009
# attribute of x  7

# %%
lst
# Out:
# [<Element 'user' at 0x000002B6095C2728>,
#  <Element 'user' at 0x000002B6095C2818>]

# %%
import socket 
mysocket = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
mysocket.connect(('data.pr4e.org',80))
command = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysocket.send(command)

while True:
    data = mysocket.recv(512)    # receive data 512bytes of data each type 
    if len(data)<1: 
        break
    print(data.decode())

#closing the connection
mysocket.close()
# Out:
# HTTP/1.1 200 OK
# Date: Mon, 19 Oct 2020 17:36:15 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already s
# ick and pale with grief
