# %% [markdown]
# # Exception Handling

# %%
if True
  print("xx")
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_10224\1497828958.py", line 1
#     if True
#            ^
# SyntaxError: invalid syntax

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\3170945453.py in <module>
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
L = [1,2,3]
L.inter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\3690470781.py in <module>
#       1 L = [1,2,3]
# ----> 2 L.inter()
#
# AttributeError: 'list' object has no attribute 'inter'

# %%
if y:
    print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\1517866578.py in <module>
# ----> 1 if y:
#       2     print(y)
#
# NameError: name 'y' is not defined

# %%
def fetcher(obj, index):
    return obj[index]

x='spam'
fetcher(x,3)
# Out:
# 'm'

# %%
fetcher(x,4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\1015091768.py in <module>
# ----> 1 fetcher(x,4)
#
# ~\AppData\Local\Temp\ipykernel_10224\2020748238.py in fetcher(obj, index)
#       1 def fetcher(obj, index):
# ----> 2     return obj[index]
#       3
#       4 x='spam'
#       5 fetcher(x,3)
#
# IndexError: string index out of range

# %%
try:
    print (fetcher(x,2))
except IndexError:
    print('Got Exception')
print('Continuing')
# Out:
# a
# Continuing

# %%
try:
    raise IndexError
except IndexError:
    print("Got Exception")
print("Continuing")
# Out:
# Got Exception
# Continuing

# %%
raise IndexError
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\3102017834.py in <module>
# ----> 1 raise IndexError
#
# IndexError:

# %%
raise IndexError("Index out of Range")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\1247675829.py in <module>
# ----> 1 raise IndexError("Index out of Range")
#
# IndexError: Index out of Range

# %%
L = [1,2,3,4]
fetcher(L,5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\264544324.py in <module>
#       1 L = [1,2,3,4]
# ----> 2 fetcher(L,5)
#
# ~\AppData\Local\Temp\ipykernel_10224\2020748238.py in fetcher(obj, index)
#       1 def fetcher(obj, index):
# ----> 2     return obj[index]
#       3
#       4 x='spam'
#       5 fetcher(x,3)
#
# IndexError: list index out of range

# %%
try:
    x = 4/0
except ArithmeticError:
    print ('Arithmetic Error')
# Out:
# Arithmetic Error

# %%
try:
    x=4/0
except ArithmeticError as ae:
    print('Arithmetic Error', ae)
# Out:
# Arithmetic Error division by zero

# %%
4/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\1580332654.py in <module>
# ----> 1 4/0
#
# ZeroDivisionError: division by zero

# %%
L=[1,2,3]
L = L + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\1858459613.py in <module>
#       1 L=[1,2,3]
# ----> 2 L = L + 4
#
# TypeError: can only concatenate list (not "int") to list

# %%
def after():
    try:
        print(fetcher(x,4))
    finally:
        print('In finally')
    print('Continuing')

# %%
after()
# Out:
# In finally
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10224\417892831.py in <module>
# ----> 1 after()
#
# ~\AppData\Local\Temp\ipykernel_10224\2541034476.py in after()
#       1 def after():
#       2     try:
# ----> 3         print(fetcher(x,4))
#       4     finally:
#       5         print('In finally')
#
# ~\AppData\Local\Temp\ipykernel_10224\2020748238.py in fetcher(obj, index)
#       1 def fetcher(obj, index):
# ----> 2     return obj[index]
#       3
#       4 x='spam'
#       5 fetcher(x,3)
#
# IndexError: string index out of range

# %%
def after():
    try:
        print(fetcher(x,4))
    except IndexError:
        print('Exception caught')
    finally:
        print('In finally')
    print('Continuing')
after()
# Out:
# Exception caught
# In finally
# Continuing

# %%
def fetcher(obj, index):
    try:
        y=4/0
        return obj[index]
    except IndexError:
        print ('Exception handled in fetcher')
def after():
    try:
        print(fetcher(x,4))
    except IndexError:
        print ('Exception handled in after')
    except ArithmeticError:
        print ('Exception handled in after for Arithmetic Error')
after()
# Out:
# Exception handled in after for Arithmetic Error
