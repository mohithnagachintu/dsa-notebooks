# %%
from smtplib import SMTP
import getpass

# %%
#context = ssl.create_default_context()

# %%
server = SMTP('smtp.gmail.com', 587)
server.starttls()
server.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [110.172.187.188]\nSIZE 35882577\n8BITMIME\nAUTH LOGIN PLAIN XOAUTH2 PLAIN-CLIENTTOKEN OAUTHBEARER XOAUTH\nENHANCEDSTATUSCODES\nPIPELINING\nSMTPUTF8')

# %%
server.login("kamakshi@cse.sastra.ac.in", getpass.getpass("Enter your password: "))
# Out:
# Enter your password: ········
# (235, b'2.7.0 Accepted')

# %%
sent_from = "kamakshi@cse.sastra.ac.in"
to = ['sumukhapravin@gmail.com', 'kamakshi@cse.sastra.ac.in']
subject = 'Message From Python Code'
body = "Hello Students! This is a test mail"

email_text = """\
From: %s
To: %s
Subject: %s

# %s
""" % (sent_from, ", ".join(to), subject, body)
server.sendmail(sent_from, to, email_text)
print ('Email sent!')
# Out:
# Email sent!

# %%
server.quit()
# Out:
# (221, b'2.0.0 closing connection mt2sm5976203pjb.17 - gsmtp')
