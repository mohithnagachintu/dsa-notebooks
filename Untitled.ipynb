# %%
st = ['a'] * 20

# %%
print('","'.join(st))
# Out:
# a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a

# %%
ans = []

# %%
ans.extend(str(20))

# %%
ans
# Out:
# ['2', '0']
