# %%
d = dict()

# %%
if 'nithin' not in d:
    d['nithin'] = []
d['nithin'].append(3)

# %%
from collections import defaultdict
d = defaultdict(list)
d['nithin'].append(3)

# %%
d = [-1] * 4

# %%
print(d[0])
# Out:
# -1

# %%
d
# Out:
# [-1, -1, -1, -1]
