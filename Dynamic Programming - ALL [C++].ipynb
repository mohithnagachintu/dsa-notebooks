// %% [markdown]
// # ALL — Dynamic Programming (Consolidated)
//
// Combined from **DSA Tracker**, **Striver SDE Sheet**, and **NeetCode All**.
//
// Organized by **category** (DSA Tracker taxonomy) → **difficulty** → problem.

// %% [markdown]
// # Linear DP

// %% [markdown]
// ## Easy

// %% [markdown]
// ##### 1. Best Time to Buy And Sell Stock - https://leetcode.com/problems/best-time-to-buy-and-sell-stock/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 2. Climbing Stairs - https://leetcode.com/problems/climbing-stairs/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 3. Divisor Game - https://leetcode.com/problems/divisor-game/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 4. Min Cost Climbing Stairs - https://leetcode.com/problems/min-cost-climbing-stairs/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 5. N-th Tribonacci Number - https://leetcode.com/problems/n-th-tribonacci-number/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 6. 4 Keys Keyboard - https://leetcode.com/problems/4-keys-keyboard/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 7. Best Time to Buy And Sell Stock II - https://leetcode.com/problems/best-time-to-buy-and-sell-stock-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 8. Best Time to Buy And Sell Stock With Cooldown - https://leetcode.com/problems/best-time-to-buy-and-sell-stock-with-cooldown/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 9. Best Time to Buy and Sell Stock with Transaction Fee - https://leetcode.com/problems/best-time-to-buy-and-sell-stock-with-transaction-fee/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 10. Check if There is a Valid Partition For The Array - https://leetcode.com/problems/check-if-there-is-a-valid-partition-for-the-array/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 11. Coin Change - https://leetcode.com/problems/coin-change/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 12. Coin Change II - https://leetcode.com/problems/coin-change-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 13. Count Strictly Increasing Subarrays - https://leetcode.com/problems/count-strictly-increasing-subarrays/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 14. Count Ways to Build Good Strings - https://leetcode.com/problems/count-ways-to-build-good-strings/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 15. Decode Ways - https://leetcode.com/problems/decode-ways/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 16. Delete And Earn - https://leetcode.com/problems/delete-and-earn/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 17. Domino and Tromino Tiling - https://leetcode.com/problems/domino-and-tromino-tiling/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 18. Filling Bookcase Shelves - https://leetcode.com/problems/filling-bookcase-shelves/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 19. Greatest Sum Divisible by Three - https://leetcode.com/problems/greatest-sum-divisible-by-three/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 20. House Robber - https://leetcode.com/problems/house-robber/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 21. Integer Break - https://leetcode.com/problems/integer-break/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 22. Knight Dialer - https://leetcode.com/problems/knight-dialer/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 23. Longest Arithmetic Subsequence of Given Difference - https://leetcode.com/problems/longest-arithmetic-subsequence-of-given-difference/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 24. Maximum Length of Pair Chain - https://leetcode.com/problems/maximum-length-of-pair-chain/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 25. Maximum Subarray Min Product - https://leetcode.com/problems/maximum-subarray-min-product/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 26. Minimum Cost For Tickets - https://leetcode.com/problems/minimum-cost-for-tickets/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 27. Paint Fence - https://leetcode.com/problems/paint-fence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 28. Paint House - https://leetcode.com/problems/paint-house/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 29. Partition Array for Maximum Sum - https://leetcode.com/problems/partition-array-for-maximum-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 30. Partition Equal Subset Sum - https://leetcode.com/problems/partition-equal-subset-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 31. Perfect Squares - https://leetcode.com/problems/perfect-squares/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 32. Sentence Screen Fitting - https://leetcode.com/problems/sentence-screen-fitting/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 33. Solving Questions With Brainpower - https://leetcode.com/problems/solving-questions-with-brainpower/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 34. Uncrossed Lines - https://leetcode.com/problems/uncrossed-lines/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 35. Unique Binary Search Trees - https://leetcode.com/problems/unique-binary-search-trees/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 36. Wiggle Subsequence - https://leetcode.com/problems/wiggle-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 37. Best Time to Buy and Sell Stock III - https://leetcode.com/problems/best-time-to-buy-and-sell-stock-iii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 38. Coin Path - https://leetcode.com/problems/coin-path/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 39. Count all Valid Pickup and Delivery Options - https://leetcode.com/problems/count-all-valid-pickup-and-delivery-options/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 40. Decode Ways II - https://leetcode.com/problems/decode-ways-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 41. Encode String with Shortest Length - https://leetcode.com/problems/encode-string-with-shortest-length/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 42. Find the Longest Valid Obstacle Course at Each Position - https://leetcode.com/problems/find-the-longest-valid-obstacle-course-at-each-position/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 43. Form Largest Integer With Digits That Add up to Target - https://leetcode.com/problems/form-largest-integer-with-digits-that-add-up-to-target/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 44. Handshakes That Don't Cross - https://leetcode.com/problems/handshakes-that-dont-cross/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 45. Maximize Score after N Operations - https://leetcode.com/problems/maximize-score-after-n-operations/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 46. Maximum Profit in Job Scheduling - https://leetcode.com/problems/maximum-profit-in-job-scheduling/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 47. Minimum Number of Taps to Open to Water a Garden - https://leetcode.com/problems/minimum-number-of-taps-to-open-to-water-a-garden/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 48. Number of Ways to Divide a Long Corridor - https://leetcode.com/problems/number-of-ways-to-divide-a-long-corridor/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 49. Optimal Account Balancing - https://leetcode.com/problems/optimal-account-balancing/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 50. Restore The Array - https://leetcode.com/problems/restore-the-array/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 51. Stone Game III - https://leetcode.com/problems/stone-game-iii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 52. Stone Game IV - https://leetcode.com/problems/stone-game-iv/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 53. Student Attendance Record II - https://leetcode.com/problems/student-attendance-record-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 54. Triples with Bitwise AND Equal To Zero - https://leetcode.com/problems/triples-with-bitwise-and-equal-to-zero/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 55. Valid Palindrome III - https://leetcode.com/problems/valid-palindrome-iii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Knapsack

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 56. 2 Keys Keyboard - https://leetcode.com/problems/2-keys-keyboard/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 57. Best Team with no Conflicts - https://leetcode.com/problems/best-team-with-no-conflicts/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 58. House Robber II - https://leetcode.com/problems/house-robber-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 59. Ones and Zeroes - https://leetcode.com/problems/ones-and-zeroes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 60. Shopping Offers - https://leetcode.com/problems/shopping-offers/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 61. Target Sum - https://leetcode.com/problems/target-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 62. Minimum Swaps To Make Sequences Increasing - https://leetcode.com/problems/minimum-swaps-to-make-sequences-increasing/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 63. Pizza With 3n Slices - https://leetcode.com/problems/pizza-with-3n-slices/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 64. Profitable Schemes - https://leetcode.com/problems/profitable-schemes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 65. Reducing Dishes - https://leetcode.com/problems/reducing-dishes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 66. Tallest Billboard - https://leetcode.com/problems/tallest-billboard/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Multi Dimensions DP

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 67. Champagne Tower - https://leetcode.com/problems/champagne-tower/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 68. Combination Sum IV - https://leetcode.com/problems/combination-sum-iv/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 69. Count Number of Teams - https://leetcode.com/problems/count-number-of-teams/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 70. Flip String to Monotone Increasing - https://leetcode.com/problems/flip-string-to-monotone-increasing/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 71. Knight Probability In Chessboard - https://leetcode.com/problems/knight-probability-in-chessboard/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 72. Largest Sum Of Averages - https://leetcode.com/problems/largest-sum-of-averages/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 73. Longest Arithmetic Subsequence - https://leetcode.com/problems/longest-arithmetic-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 74. Longest Ideal Subsequence - https://leetcode.com/problems/longest-ideal-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 75. Maximum Alternating Subsequence Sum - https://leetcode.com/problems/maximum-alternating-subsequence-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 76. Maximum Number of Points with Cost - https://leetcode.com/problems/maximum-number-of-points-with-cost/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 77. Minimum Falling Path Sum - https://leetcode.com/problems/minimum-falling-path-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 78. Number of Dice Rolls with Target Sum - https://leetcode.com/problems/number-of-dice-rolls-with-target-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 79. Number Of Sets Of K Non Overlapping Line Segments - https://leetcode.com/problems/number-of-sets-of-k-non-overlapping-line-segments/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 80. Out of Boundary Paths - https://leetcode.com/problems/out-of-boundary-paths/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 81. Stone Game II - https://leetcode.com/problems/stone-game-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 82. Triangle - https://leetcode.com/problems/triangle/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 83. Video Stitching - https://leetcode.com/problems/video-stitching/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 84. Best Time To Buy And Sell Stock Iv - https://leetcode.com/problems/best-time-to-buy-and-sell-stock-iv/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 85. Build Array Where You Can Find The Maximum Exactly K Comparisons - https://leetcode.com/problems/build-array-where-you-can-find-the-maximum-exactly-k-comparisons/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 86. Count All Possible Routes - https://leetcode.com/problems/count-all-possible-routes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 87. Count Vowels Permutation - https://leetcode.com/problems/count-vowels-permutation/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 88. Create Maximum Number - https://leetcode.com/problems/create-maximum-number/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 89. Dice Roll Simulation - https://leetcode.com/problems/dice-roll-simulation/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 90. Freedom Trail - https://leetcode.com/problems/freedom-trail/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 91. Frog Jump - https://leetcode.com/problems/frog-jump/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 92. Longest Increasing Path In a Matrix - https://leetcode.com/problems/longest-increasing-path-in-a-matrix/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 93. Maximum Value of K Coins from Piles - https://leetcode.com/problems/maximum-value-of-k-coins-from-piles/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 94. Minimum Difficulty of a Job Schedule - https://leetcode.com/problems/minimum-difficulty-of-a-job-schedule/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 95. Minimum Distance To Type A Word Using Two Fingers - https://leetcode.com/problems/minimum-distance-to-type-a-word-using-two-fingers/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 96. Minimum Falling Path Sum II - https://leetcode.com/problems/minimum-falling-path-sum-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 97. Minimum Number Of Refueling Stops - https://leetcode.com/problems/minimum-number-of-refueling-stops/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 98. Number of Music Playlists - https://leetcode.com/problems/number-of-music-playlists/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 99. Number Of Ways Of Cutting A Pizza - https://leetcode.com/problems/number-of-ways-of-cutting-a-pizza/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 100. Number Of Ways To Paint N 3 Grid - https://leetcode.com/problems/number-of-ways-to-paint-n-3-grid/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 101. Number of Ways to Rearrange Sticks With K Sticks Visible - https://leetcode.com/problems/number-of-ways-to-rearrange-sticks-with-k-sticks-visible/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 102. Paint House II - https://leetcode.com/problems/paint-house-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 103. Paint House Iii - https://leetcode.com/problems/paint-house-iii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 104. Painting the Walls - https://leetcode.com/problems/painting-the-walls/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 105. Split Array Largest Sum - https://leetcode.com/problems/split-array-largest-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 106. Split Array With Same Average - https://leetcode.com/problems/split-array-with-same-average/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Interval DP

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 107. Arithmetic Slices - https://leetcode.com/problems/arithmetic-slices/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 108. Guess Number Higher Or Lower Ii - https://leetcode.com/problems/guess-number-higher-or-lower-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 109. Last Stone Weight II - https://leetcode.com/problems/last-stone-weight-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 110. Minimum Cost Tree From Leaf Values - https://leetcode.com/problems/minimum-cost-tree-from-leaf-values/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 111. Minimum Score Triangulation Of Polygon - https://leetcode.com/problems/minimum-score-triangulation-of-polygon/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 112. Palindromic Substrings - https://leetcode.com/problems/palindromic-substrings/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 113. Predict The Winner - https://leetcode.com/problems/predict-the-winner/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 114. Stone Game - https://leetcode.com/problems/stone-game/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 115. Stone Game Vii - https://leetcode.com/problems/stone-game-vii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 116. Allocate Mailboxes - https://leetcode.com/problems/allocate-mailboxes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 117. Burst Balloons - https://leetcode.com/problems/burst-balloons/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 118. Minimum Cost to Cut a Stick - https://leetcode.com/problems/minimum-cost-to-cut-a-stick/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 119. Minimum Cost To Merge Stones - https://leetcode.com/problems/minimum-cost-to-merge-stones/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 120. Remove Boxes - https://leetcode.com/problems/remove-boxes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 121. Stone Game V - https://leetcode.com/problems/stone-game-v/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 122. Strange Printer - https://leetcode.com/problems/strange-printer/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 123. Valid Permutations For Di Sequence - https://leetcode.com/problems/valid-permutations-for-di-sequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # bit DP

// %% [markdown]
// ## Easy

// %% [markdown]
// ##### 124. Counting Bits - https://leetcode.com/problems/counting-bits/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 125. Can I Win - https://leetcode.com/problems/can-i-win/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 126. Partition to K Equal Sum Subsets - https://leetcode.com/problems/partition-to-k-equal-sum-subsets/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 127. Distribute Repeating Integers - https://leetcode.com/problems/distribute-repeating-integers/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 128. Find Minimum Time To Finish All Jobs - https://leetcode.com/problems/find-minimum-time-to-finish-all-jobs/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 129. Maximize Grid Happiness - https://leetcode.com/problems/maximize-grid-happiness/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 130. Maximum Number Of Achievable Transfer Requests - https://leetcode.com/problems/maximum-number-of-achievable-transfer-requests/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 131. Maximum Students Taking Exam - https://leetcode.com/problems/maximum-students-taking-exam/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 132. Minimum Cost To Connect Two Groups Of Points - https://leetcode.com/problems/minimum-cost-to-connect-two-groups-of-points/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 133. Number Of Ways To Wear Different Hats To Each Other - https://leetcode.com/problems/number-of-ways-to-wear-different-hats-to-each-other/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 134. Shortest Path Visiting All Nodes - https://leetcode.com/problems/shortest-path-visiting-all-nodes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 135. Smallest Sufficient Team - https://leetcode.com/problems/smallest-sufficient-team/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 136. Stickers to Spell Word - https://leetcode.com/problems/stickers-to-spell-word/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Digit DP

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 137. Count Numbers with Unique Digits - https://leetcode.com/problems/count-numbers-with-unique-digits/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 138. Count of Integers - https://leetcode.com/problems/count-of-integers/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 139. Count Special Integers - https://leetcode.com/problems/count-special-integers/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 140. Non Negative Integers Without Consecutive Ones - https://leetcode.com/problems/non-negative-integers-without-consecutive-ones/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 141. Number of Digit One - https://leetcode.com/problems/number-of-digit-one/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 142. Numbers At Most N Given Digit Set - https://leetcode.com/problems/numbers-at-most-n-given-digit-set/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 143. Numbers With Repeated Digits - https://leetcode.com/problems/numbers-with-repeated-digits/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # DP on Trees

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 144. House Robber III - https://leetcode.com/problems/house-robber-iii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 145. Linked List in Binary Tree - https://leetcode.com/problems/linked-list-in-binary-tree/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 146. Longest Zigzag Path In A Binary Tree - https://leetcode.com/problems/longest-zigzag-path-in-a-binary-tree/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 147. Maximum Product Of Splitted Binary Tree - https://leetcode.com/problems/maximum-product-of-splitted-binary-tree/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 148. Unique Binary Search Trees II - https://leetcode.com/problems/unique-binary-search-trees-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 149. Binary Tree Cameras - https://leetcode.com/problems/binary-tree-cameras/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 150. Maximum Sum Bst In Binary Tree - https://leetcode.com/problems/maximum-sum-bst-in-binary-tree/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 151. Number Of Ways To Reorder Array To Get Same Bst - https://leetcode.com/problems/number-of-ways-to-reorder-array-to-get-same-bst/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # String DP

// %% [markdown]
// ## Easy

// %% [markdown]
// ##### 152. Is Subsequence - https://leetcode.com/problems/is-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 153. Longest Happy String - https://leetcode.com/problems/longest-happy-string/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 154. Longest String Chain - https://leetcode.com/problems/longest-string-chain/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 155. Minimum Ascii Delete Sum For Two Strings - https://leetcode.com/problems/minimum-ascii-delete-sum-for-two-strings/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 156. Palindrome Partitioning - https://leetcode.com/problems/palindrome-partitioning/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 157. Unique Substrings In Wraparound String - https://leetcode.com/problems/unique-substrings-in-wraparound-string/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 158. Word Break - https://leetcode.com/problems/word-break/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 159. Concatenated Words - https://leetcode.com/problems/concatenated-words/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 160. Count Different Palindromic Subsequences - https://leetcode.com/problems/count-different-palindromic-subsequences/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 161. Count The Repetitions - https://leetcode.com/problems/count-the-repetitions/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 162. Distinct Subsequences - https://leetcode.com/problems/distinct-subsequences/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 163. Distinct Subsequences Ii - https://leetcode.com/problems/distinct-subsequences-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 164. Find All Good Strings - https://leetcode.com/problems/find-all-good-strings/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 165. Longest Chunked Palindrome Decomposition - https://leetcode.com/problems/longest-chunked-palindrome-decomposition/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 166. Longest Valid Parentheses - https://leetcode.com/problems/longest-valid-parentheses/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 167. Number of Ways to Form a Target String Given a Dictionary - https://leetcode.com/problems/number-of-ways-to-form-a-target-string-given-a-dictionary/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 168. Palindrome Partitioning Iii - https://leetcode.com/problems/palindrome-partitioning-iii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 169. Palindrome Partitioning – II - https://leetcode.com/problems/palindrome-partitioning-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 170. String Compression II - https://leetcode.com/problems/string-compression-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 171. Word Break II - https://leetcode.com/problems/word-break-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Probability DP

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 172. Airplane Seat Assignment Probability - https://leetcode.com/problems/airplane-seat-assignment-probability/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 173. New 21 Game - https://leetcode.com/problems/new-21-game/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 174. Soup Servings - https://leetcode.com/problems/soup-servings/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Classic DPs

// %% [markdown]
// ### A. Cadane's Algorithm

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 175. Bitwise Ors Of Subarrays - https://leetcode.com/problems/bitwise-ors-of-subarrays/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 176. K Concatenation Maximum Sum - https://leetcode.com/problems/k-concatenation-maximum-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 177. Largest Divisible Subset - https://leetcode.com/problems/largest-divisible-subset/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 178. Length of Longest Fibonacci Subsequence - https://leetcode.com/problems/length-of-longest-fibonacci-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 179. Longest Turbulent Subarray - https://leetcode.com/problems/longest-turbulent-subarray/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 180. Maximum Product Subarray - https://leetcode.com/problems/maximum-product-subarray/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 181. Maximum Subarray - https://leetcode.com/problems/maximum-subarray/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 182. Maximum Subarray Sum With One Deletion - https://leetcode.com/problems/maximum-subarray-sum-with-one-deletion/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ### B. LCS

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 183. Edit Distance - https://leetcode.com/problems/edit-distance/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 184. Interleaving String - https://leetcode.com/problems/interleaving-string/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 185. Longest Common Subsequence - https://leetcode.com/problems/longest-common-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 186. Longest Palindromic Subsequence - https://leetcode.com/problems/longest-palindromic-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 187. Longest Palindromic Substring - https://leetcode.com/problems/longest-palindromic-substring/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 188. Maximum Length Of Repeated Subarray - https://leetcode.com/problems/maximum-length-of-repeated-subarray/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 189. Max Dot Product Of Two Subsequences - https://leetcode.com/problems/max-dot-product-of-two-subsequences/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 190. Minimum Insertion Steps To Make A String Palindrome - https://leetcode.com/problems/minimum-insertion-steps-to-make-a-string-palindrome/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 191. Regular Expression Matching - https://leetcode.com/problems/regular-expression-matching/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 192. Shortest Common Supersequence - https://leetcode.com/problems/shortest-common-supersequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 193. Wildcard Matching - https://leetcode.com/problems/wildcard-matching/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ### C. LIS

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 194. Longest Increasing Subsequence - https://leetcode.com/problems/longest-increasing-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 195. Number of Longest Increasing Subsequence - https://leetcode.com/problems/number-of-longest-increasing-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 196. Delete Columns To Make Sorted Iii - https://leetcode.com/problems/delete-columns-to-make-sorted-iii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 197. Make Array Strictly Increasing - https://leetcode.com/problems/make-array-strictly-increasing/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 198. Maximum Height By Stacking Cuboids - https://leetcode.com/problems/maximum-height-by-stacking-cuboids/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 199. Minimum Number of Removals to Make Mountain Array - https://leetcode.com/problems/minimum-number-of-removals-to-make-mountain-array/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 200. Russian Doll Envelopes - https://leetcode.com/problems/russian-doll-envelopes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ### D. 2D Grid Traversal

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 201. Maximum Non Negative Product In A Matrix - https://leetcode.com/problems/maximum-non-negative-product-in-a-matrix/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 202. Minimum Path Sum - https://leetcode.com/problems/minimum-path-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 203. Unique Paths - https://leetcode.com/problems/unique-paths/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 204. Unique Paths II - https://leetcode.com/problems/unique-paths-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 205. Where Will The Ball Fall - https://leetcode.com/problems/where-will-the-ball-fall/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 206. Cherry Pickup - https://leetcode.com/problems/cherry-pickup/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 207. Cherry Pickup II - https://leetcode.com/problems/cherry-pickup-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 208. Dungeon Game - https://leetcode.com/problems/dungeon-game/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 209. Kth Smallest Instructions - https://leetcode.com/problems/kth-smallest-instructions/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 210. Number Of Paths With Max Score - https://leetcode.com/problems/number-of-paths-with-max-score/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ### E. Cumulative Sum

// %% [markdown]
// ## Easy

// %% [markdown]
// ##### 211. Range Sum Query - Immutable - https://leetcode.com/problems/range-sum-query-immutable/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 212. Count Square Submatrices with All Ones - https://leetcode.com/problems/count-square-submatrices-with-all-ones/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 213. Count Submatrices With All Ones - https://leetcode.com/problems/count-submatrices-with-all-ones/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 214. Largest 1 Bordered Square - https://leetcode.com/problems/largest-1-bordered-square/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 215. Largest Plus Sign - https://leetcode.com/problems/largest-plus-sign/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 216. Matrix Block Sum - https://leetcode.com/problems/matrix-block-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 217. Maximal Square - https://leetcode.com/problems/maximal-square/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 218. Maximum Points You Can Obtain From Cards - https://leetcode.com/problems/maximum-points-you-can-obtain-from-cards/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 219. Push Dominoes - https://leetcode.com/problems/push-dominoes/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 220. Range Sum Query 2D Immutable - https://leetcode.com/problems/range-sum-query-2d-immutable/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 221. Ways To Make A Fair Array - https://leetcode.com/problems/ways-to-make-a-fair-array/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 222. Get The Maximum Score - https://leetcode.com/problems/get-the-maximum-score/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 223. Max Sum Of Rectangle No Larger Than K - https://leetcode.com/problems/max-sum-of-rectangle-no-larger-than-k/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 224. Maximum Rectangle Area with all 1’s - https://leetcode.com/problems/maximal-rectangle/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 225. Maximum Sum of 3 Non-Overlapping Subarrays - https://leetcode.com/problems/maximum-sum-of-3-non-overlapping-subarrays/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 226. Number of Submatrices that Sum to Target - https://leetcode.com/problems/number-of-submatrices-that-sum-to-target/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 227. Super Washing Machines - https://leetcode.com/problems/super-washing-machines/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ### F. Hashmap (SubArray)

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 228. Continuous Subarray Sum - https://leetcode.com/problems/continuous-subarray-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 229. Find Two Non Overlapping Sub Arrays Each With Target Sum - https://leetcode.com/problems/find-two-non-overlapping-sub-arrays-each-with-target-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 230. Maximum Number Of Non Overlapping Subarrays With Sum Equals Target - https://leetcode.com/problems/maximum-number-of-non-overlapping-subarrays-with-sum-equals-target/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # DP + Alpha (Tricks/DS)

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 231. Arithmetic Slices II - https://leetcode.com/problems/arithmetic-slices-ii-subsequence/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 232. Constrained Subsequence Sum - https://leetcode.com/problems/constrained-subsequence-sum/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 233. Delivering Boxes From Storage To Ports - https://leetcode.com/problems/delivering-boxes-from-storage-to-ports/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 234. Odd Even Jump - https://leetcode.com/problems/odd-even-jump/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Insertion DP

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 235. K Inverse Pairs Array - https://leetcode.com/problems/k-inverse-pairs-array/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Graph DP

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 236. Cheapest Flights Within K Stops - https://leetcode.com/problems/cheapest-flights-within-k-stops/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 237. Find The Shortest Superstring - https://leetcode.com/problems/find-the-shortest-superstring/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Memoization

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 238. Minimum Jumps To Reach Home - https://leetcode.com/problems/minimum-jumps-to-reach-home/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 239. Jump Game V - https://leetcode.com/problems/jump-game-v/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 240. Minimum Number of Days to Eat N Oranges - https://leetcode.com/problems/minimum-number-of-days-to-eat-n-oranges/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 241. Number of Ways to Stay in the Same Place After Some Steps - https://leetcode.com/problems/number-of-ways-to-stay-in-the-same-place-after-some-steps/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 242. Scramble String - https://leetcode.com/problems/scramble-string/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 243. Tiling A Rectangle With The Fewest Squares - https://leetcode.com/problems/tiling-a-rectangle-with-the-fewest-squares/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Binary Lifting

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 244. Kth Ancestor Of A Tree Node - https://leetcode.com/problems/kth-ancestor-of-a-tree-node/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// # Math

// %% [markdown]
// ## Medium

// %% [markdown]
// ##### 245. Count Sorted Vowel Strings - https://leetcode.com/problems/count-sorted-vowel-strings/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 246. Ugly Number II - https://leetcode.com/problems/ugly-number-ii/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ## Hard

// %% [markdown]
// ##### 247. Largest Multiple Of Three - https://leetcode.com/problems/largest-multiple-of-three/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 248. Least Operators To Express Number - https://leetcode.com/problems/least-operators-to-express-number/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 249. Minimum Number of One Bit Operations to Make Integers Zero - https://leetcode.com/problems/minimum-one-bit-operations-to-make-integers-zero/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 250. Race Car - https://leetcode.com/problems/race-car/

// %%
#include <bits/stdc++.h>
using namespace std;

// %% [markdown]
// ##### 251. Super Egg Drop - https://leetcode.com/problems/super-egg-drop/

// %%
#include <bits/stdc++.h>
using namespace std;
